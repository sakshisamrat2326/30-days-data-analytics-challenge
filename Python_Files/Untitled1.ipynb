# %%
class Computer: #class name in Capital by convention
    def config(self):
        print("red,good,cool")


#object creation
com1=Computer()
com2=Computer()

#Computer.config(com1)
#Computer.config(com2)
com1.config()
com2.config()
# Out:
# red,good,cool
# red,good,cool
