# %%
import numpy as np
import matplotlib.pyplot as plt
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

print("==== Zomato sales analysis ==== ")
print("\n Sales data shape", sales_data.shape)
print("\n Sample data for 1st 3 restau: ", sales_data[:3])
# Out:
# ==== Zomato sales analysis ====
#
#  Sales data shape (5, 5)
#
#  Sample data for 1st 3 restau:  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
#total sales per year
display(np.sum(sales_data,axis=0))
yearly_total=np.sum(sales_data[:,1:],axis=0)
display(yearly_total)
# Out:
# array([     15,  810000,  945000, 1085000, 1240000])
# array([ 810000,  945000, 1085000, 1240000])

# %%
#minimum sales per restaurant 
min_sales=np.min(sales_data[:,1:],axis=1)
display(min_sales)
# Out:
# array([150000, 120000, 200000, 180000, 160000])

# %%
#max sales per year (thus col => top to bottom
max_sales=np.max(sales_data[:, 1:],axis=0)
display(max_sales)
# Out:
# array([200000, 230000, 260000, 300000])

# %%
#avg_sales=npavg sales per restaurant (=> left to right=row=axis=1)
avg_sales=np.mean(sales_data[:,1:],axis=1)
display(avg_sales)
# Out:
# array([200000., 152500., 247500., 225000., 195000.])

# %%
#cumulative sales
cumsum=np.cumsum(sales_data[:,1:],axis=1)
display(cumsum)
# Out:
# array([[150000, 330000, 550000, 800000],
#        [120000, 260000, 420000, 610000],
#        [200000, 430000, 690000, 990000],
#        [180000, 390000, 630000, 900000],
#        [160000, 345000, 550000, 780000]])

# %%
plt.figure(figsize=(10,6))
plt.plot(np.mean(cumsum,axis=0))
plt.title("AVg cumulative sales accross all restaurants")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
dt = np.dtype([('name', 'S10'), ('score', 'f4')])
arr = np.array([('Alice', 85.5), ('Bob', 90.0)], dtype=dt)

# %%
dt
# Out:
# dtype([('name', 'S10'), ('score', '<f4')])

# %%
arr
# Out:
# array([(b'Alice', 85.5), (b'Bob', 90. )],
#       dtype=[('name', 'S10'), ('score', '<f4')])
